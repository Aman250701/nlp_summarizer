# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
import os
os.chdir("/content/drive/MyDrive/NLP Summarizer/")

# %%
from driver import driver_function
driver_function('annual_reports')
